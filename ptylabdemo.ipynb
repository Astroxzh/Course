# %% [markdown]
# # PtyLab.py demo
# In this short tutorial we will simulate a conventional ptychography experiment. To simulate a ptychography experiment the following steps have to be performed.
#
# 1. The geometry of the experiment needs to be specified. The following variables need to be defined.
#     - Wavelength of the illuminating beam
#     - Sample to detector distance (z0)
#     - Detector pixel number (Nd)
#     - Detector pixel size (dxd)
# 2. The illuminating beam (which we refer to as probe) has to be defined
# 3. The object to be simulated needs to be defined
# 4. The scan grid, i.e. the coordinates with which the object is scanned, must be generated.
# 5. For each position a diffraction pattern needs to be calculated.
#
# Finally, at the end of this tutorial, the object is reconstructed from the created diffraction images.

# %% [markdown]
# ## 0. Installation
#
# Installing the dependencies of `ptylab`

# %%
# %pip install git+https://github.com/PtyLab/PtyLab.py.git
# Out:
# Collecting git+https://github.com/PtyLab/PtyLab.py.git
#   Cloning https://github.com/PtyLab/PtyLab.py.git to /tmp/pip-req-build-0aw1gx6y
#   Running command git clone --filter=blob:none --quiet https://github.com/PtyLab/PtyLab.py.git /tmp/pip-req-build-0aw1gx6y
#   Resolved https://github.com/PtyLab/PtyLab.py.git to commit 90a04471e9467224b9f598a4e5a20958708c7f0a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting PyQt5<6.0.0,>=5.15.10 (from ptylab==0.2.1)
#   Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting PyQt5-Qt5 (from ptylab==0.2.1)
#   Downloading PyQt5_Qt5-5.15.16-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Requirement already satisfied: bokeh<4.0.0,>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from ptylab==0.2.1) (3.6.2)
# Requirement already satisfied: h5py<4.0.0,>=3.9.0 in /usr/local/lib/python3.10/dist-packages (from ptylab==0.2.1) (3.12.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from ptylab==0.2.1) (3.10.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22 in /usr/local/lib/python3.10/dist-packages (from ptylab==0.2.1) (1.26.4)
# Collecting pyqtgraph<0.14.0,>=0.13.3 (from ptylab==0.2.1)
#   Downloading pyqtgraph-0.13.7-py3-none-any.whl.metadata (1.3 kB)
# Collecting scikit-image<0.22.0,>=0.21.0 (from ptylab==0.2.1)
#   Downloading scikit_image-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from ptylab==0.2.1) (1.6.0)
# Requirement already satisfied: scipy<2.0.0,>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from ptylab==0.2.1) (1.13.1)
# Requirement already satisfied: tables<4.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from ptylab==0.2.1) (3.10.1)
# Requirement already satisfied: tensorflow<3.0.0,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from ptylab==0.2.1) (2.17.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from ptylab==0.2.1) (4.67.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (3.1.5)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (1.3.1)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (24.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/dist-packages (from bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (2024.9.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->ptylab==0.2.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->ptylab==0.2.1) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->ptylab==0.2.1) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->ptylab==0.2.1) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->ptylab==0.2.1) (2.8.2)
# Collecting PyQt5-sip<13,>=12.15 (from PyQt5<6.0.0,>=5.15.10->ptylab==0.2.1)
#   Downloading PyQt5_sip-12.16.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (421 bytes)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image<0.22.0,>=0.21.0->ptylab==0.2.1) (3.4.2)
# Requirement already satisfied: imageio>=2.27 in /usr/local/lib/python3.10/dist-packages (from scikit-image<0.22.0,>=0.21.0->ptylab==0.2.1) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image<0.22.0,>=0.21.0->ptylab==0.2.1) (2024.12.12)
# Collecting PyWavelets>=1.1.1 (from scikit-image<0.22.0,>=0.21.0->ptylab==0.2.1)
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: lazy_loader>=0.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image<0.22.0,>=0.21.0->ptylab==0.2.1) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.3.0->ptylab==0.2.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.3.0->ptylab==0.2.1) (3.5.0)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from tables<4.0.0,>=3.8.0->ptylab==0.2.1) (2.10.2)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from tables<4.0.0,>=3.8.0->ptylab==0.2.1) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from tables<4.0.0,>=3.8.0->ptylab==0.2.1) (2.7.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from tables<4.0.0,>=3.8.0->ptylab==0.2.1) (4.12.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (0.45.1)
# Requirement already satisfied: ndindex>=1.4 in /usr/local/lib/python3.10/dist-packages (from blosc2>=2.3.0->tables<4.0.0,>=3.8.0->ptylab==0.2.1) (1.9.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from blosc2>=2.3.0->tables<4.0.0,>=3.8.0->ptylab==0.2.1) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (3.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (0.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh<4.0.0,>=3.2.1->ptylab==0.2.1) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow<3.0.0,>=2.14.0->ptylab==0.2.1) (0.1.2)
# Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 44.2 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.16-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 14.3 MB/s eta 0:00:00
# Downloading pyqtgraph-0.13.7-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 59.8 MB/s eta 0:00:00
# Downloading scikit_image-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.8 MB/s eta 0:00:00
# Downloading PyQt5_sip-12.16.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.8/270.8 kB 12.4 MB/s eta 0:00:00
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 63.7 MB/s eta 0:00:00
# Building wheels for collected packages: ptylab
#   Building wheel for ptylab (pyproject.toml) ... done
#   Created wheel for ptylab: filename=ptylab-0.2.1-py3-none-any.whl size=137588 sha256=441d99e42ae2d3a99c8e2865eacb3dc1d0ec628c9a166319fd59d5c04baa57ca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a6ere499/wheels/d7/a6/40/031893a4fde745bc8e8f6d758b46ef3509fd5cd13b7a437e74
# Successfully built ptylab
# Installing collected packages: PyQt5-Qt5, PyWavelets, pyqtgraph, PyQt5-sip, scikit-image, PyQt5, ptylab
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.25.0
#     Uninstalling scikit-image-0.25.0:
#       Successfully uninstalled scikit-image-0.25.0
# Successfully installed PyQt5-5.15.11 PyQt5-Qt5-5.15.16 PyQt5-sip-12.16.1 PyWavelets-1.8.0 ptylab-0.2.1 pyqtgraph-0.13.7 scikit-image-0.21.0

# %% [markdown]
# ## 1. Geometry of the experiment
#
# First we need to import all necessary packages.

# %%
# First all required modules must be imported
import numpy as np
from PtyLab.utils.utils import circ, gaussian2D, cart2pol
from PtyLab.utils.scanGrids import GenerateNonUniformFermat
from PtyLab.Operators.Operators import aspw
from PtyLab.utils.visualisation import hsvplot, absplot, show3Dslider
import matplotlib.pylab as plt
from scipy.signal import convolve2d

# %% [markdown]
# In the next step we define the geometry of the experiment and calculate the grids in the sample and detector plane. The geometry of the experiment for a standard conventional ptychography experiment is defined by three parameter:
#
# 1. The wavelength of the illuminating beam, which we assume here to be 632.8 nm
# 2. The distance between the sample and the detector (which we name zo)
# 3. The shape (Nd) and pixelsize (dxd) of the detector

# %%
# Set the geometry of the Experiment
wavelength = 632.8e-9
zo = 5e-2
Nd = 2**7
dxd = 16 * 4.5e-6

# Calculate the length of the detector
Ld = Nd * dxd

# probe coordinates
dxp = wavelength * zo / Ld
Np = Nd
Lp = dxp * Np
xp = np.arange(-Np // 2, Np // 2) * dxp
Xp, Yp = np.meshgrid(xp, xp)

# object coordinates
No = 2**9
dxo = dxp
Lo = dxo * No
xo = np.arange(-No // 2, No // 2) * dxo
Xo, Yo = np.meshgrid(xo, xo)

# %% [markdown]
# ## 2. Definition of the illuminating beam
# In the next step we define the beam (probe), which we want to use for our simulation. Here, a pinhole is simulated which is convolved with a gaussian kernel.

# %%
# generate illumination
# note: simulate focused beam
# goal: 1:1 image iris through (low-NA) lens with focal length f onto an object
f = 5e-3  # focal length of lens, creating a focused probe
pinhole = circ(Xp, Yp, Lp / 2)
pinhole = convolve2d(pinhole, gaussian2D(5, 1).astype(np.float32), mode="same")

# %% [markdown]
# Next, we propagate probe on the sample using a propagator and use the matplotlib to plot the probe.

# %%
# propagate to lens
probe = aspw(pinhole, 2 * f, wavelength, Lp, is_FT=False)[0]

# multiply with quadratic phase and aperture
aperture = circ(Xp, Yp, 3 * Lp / 4)
aperture = convolve2d(aperture, gaussian2D(5, 3).astype(np.float32), mode="same")
probe = (
    probe
    * np.exp(-1.0j * 2 * np.pi / wavelength * (Xp**2 + Yp**2) / (2 * f))
    * aperture
)
probe = aspw(probe, 2 * f, wavelength, Lp, is_FT=False)[0]

plt.figure(figsize=(10, 4), num=1)
ax1 = plt.subplot(121)
hsvplot(probe, ax=ax1, pixelSize=dxp, axisUnit="mm")
ax1.set_title("complex probe")
ax2 = plt.subplot(122)
absplot(abs(probe), ax=ax2, pixelSize=dxp, axisUnit="mm", cmap="gray")
ax2.set_title("probe intensity")
# plt.show(block=False)
# Out:
# Text(0.5, 1.0, 'probe intensity')

# %% [markdown]
# ## 3. Definition of an object
# In this example we define a binary spiral as a test object. The object needs to have a larger array size than the probe, since the probe is scanned over the object.

# %%
# generate object
d = 1e-3  # the smaller this parameter the larger the spatial frequencies in the simulated object
b = 33  # topological charge (feel free to play with this number)
theta, rho = cart2pol(Xo, Yo)
t = (1 + np.sign(np.sin(b * theta + 2 * np.pi * (rho / d) ** 2))) / 2
t = t * circ(Xo, Yo, Lo) * (1 - circ(Xo, Yo, 200 * dxo)) + circ(Xo, Yo, 130 * dxo)
obj = convolve2d(t, gaussian2D(5, 3), mode="same")  # smooth edges

plt.figure(figsize=(5, 5))
ax = plt.axes()
hsvplot(np.squeeze(obj), ax=ax)
ax.set_title("complex Object")
plt.show(block=False)

# %% [markdown]
# ## 4. Definition of the scan map
# In the next step we create a scan grid with 100 points. For this purpose, we use a ptyLab internal function that generates a grid in which the scan points are distributed as homogeneously as possible (Fermat's spiral).

# %%
def GenerateRectangularPeriodicGrid(num_x, num_y, width, height):
  """
  Generate a rectangular periodic scan grid.
  Parameters:
  num_x (int): Number of points along the x-direction.
  num_y (int): Number of points along the y-direction.
  width (float): Total width of the rectangular grid.
  height (float): Total height of the rectangular grid.
  Returns:
  x_coords (numpy.ndarray): x-coordinates of the grid points.
  y_coords (numpy.ndarray): y-coordinates of the grid points.
  """
  # Generate linearly spaced points along x and y directions
  x = np.linspace(-width, width, num_x, endpoint=False)
  y = np.linspace(-height, height, num_y, endpoint=False)
  # Create a grid using meshgrid
  x_coords, y_coords = np.meshgrid(x, y)
  # Flatten the arrays to get 1D arrays of x and y coordinates
  x_coords = x_coords.flatten()
  y_coords = y_coords.flatten()
  return y_coords, x_coords

# %%
from re import X
numPoints = 100  # number of points
radius = 100  # radius of final scan grid (in pixels)
p = 1  # p = 1 is standard Fermat;  p > 1 yields more points towards the center of grid
# y_coord, x_coord = GenerateNonUniformFermat(numPoints, radius=radius, power=p)

# question 6
num_x = 10
num_y = 10
width = 30
height = 30
y_coord, x_coord = GenerateRectangularPeriodicGrid(num_x, num_y, width, height)

# question 3
# y_coord, x_coord = [y_coord[51:], x_coord[51:]] # [6:],[11:]

#question 4
# y_coord, x_coord = [y_coord[:-51], x_coord[:-51]] # [:-6] [:-11]

# show scan grid
plt.figure(figsize=(5, 5))
plt.plot(y_coord, x_coord, "o")
plt.title("scan grid")
plt.show(block=False)

# %% [markdown]
# In the next step we calculate the physical coordinates (in meters) and save them together in a single array, which we call encoder. The scan positions are plotted for illustration on the simulated object.

# %%
# Calculate
encoder = np.vstack((y_coord * dxo, x_coord * dxo)).T

# prevent negative indices by centering spiral coordinates on object
positions = np.round(encoder / dxo)
offset = -50 # question 1 origins 50
positions = (positions + No // 2 - Np // 2 + offset).astype(int)

# get number of positions
numFrames = len(x_coord)

# show scan grid on object
plt.figure(figsize=(5, 5))
ax1 = plt.axes()
hsvplot(np.squeeze(obj), ax=ax1)
ax1.plot(positions[:, 1] + Np // 2, positions[:, 0] + Np // 2, ".", c="red")
ax1.set_title("Scan grid on sample")
plt.show(block=False)

# %% [markdown]
# ## 5. Calculate diffraction data
# Finally we have all the information to calculate the diffraction patterns. For this purpose we create a 3-dimensionale array, which is used to store for each position the diffraction data. We name this array ptychogram.

# %%
# generate the ptychogram array
ptychogram = np.zeros((numFrames, Nd, Nd))

# %% [markdown]
# In the next step, we iterate through all the calculated positions and slice the object according to the size of the probe-array. The slice is named object patch. Since the object patch has the same size as the sample, the exit-surface-wave (esw) can be calculated in the next step. The esw represents the electric field directly behind the sample. Thus, the electric field in the detector plane can be calculated by the Fourier transform of the esw. Here it is assumed that the far field approximation is valid.

# %%
for loop in np.arange(numFrames):
    # get object patch
    row, col = positions[loop]
    sy = slice(row, row + Np)
    sx = slice(col, col + Np)
    # note that object patch has size of probe array
    objectPatch = obj[..., sy, sx].copy()
    # multiply each probe mode with object patch
    esw = objectPatch * probe
    # generate diffraction data, propagate the esw to the detector plane
    ESW = np.fft.fftshift(np.fft.fft2(np.fft.ifftshift(esw), norm="ortho"))
    # save data in ptychogram
    ptychogram[loop] = abs(ESW) ** 2

# %%
# question 2
# print(np.shape(ptychogram))
# ptychogram = ptychogram[:, 32:96, 32:96]
# Out:
# (100, 128, 128)

# %% [markdown]
# Next the ptychogram is plotted using a ptyLab plotting function.

# %%
# Show the calculated diffraction data on an interactive gui backend such as qt
# show3Dslider(np.log(ptychogram))

# %% [markdown]
# ## 6. Reconstruction of the simulated data
#
# Finally, the object is reconstructed from the generated diffraction data. For this purpose, a ptyLab reconstruction script was prepared. The script starts the reconstruction process and therefore retrieves the object and probe. The structure and functionality of the reconstruction script will be explained in the next tutorial.

# %%
from PtyLab import ExperimentalData
from PtyLab import Reconstruction
from PtyLab import Monitor
from PtyLab import Params
from PtyLab import Engines
import matplotlib as mpl

# uncomment below for showing reconstructions with interactive qt backend instead of inline
# mpl.use("qt5Agg")

# %%
## initialize the ExperimentalData class and set values
exampleData = ExperimentalData(operationMode="CPM")

# check the requiredFields and the optionalFields of the ExperimentalData class
print(exampleData.requiredFields)
print(exampleData.optionalFields)
# Out:
# ['ptychogram', 'wavelength', 'encoder', 'dxd', 'zo']
# ['entrancePupilDiameter', 'spectralDensity', 'theta', 'emptyBeam']

# %%
# fill up the requiredFields
exampleData.ptychogram = ptychogram
exampleData.wavelength = wavelength
exampleData.encoder = encoder
exampleData.dxd = dxd
exampleData.zo = zo #+ 1e-2 # question 5
# then fill up optionalFields. If not used, set the values to None
exampleData.entrancePupilDiameter = 150e-6  # initial estimate of beam diameter
exampleData.spectralDensity = None  # used in polychromatic ptychography
exampleData.theta = None  # used in tiltPlane reflection ptychography

# call _setData to auto-calculate all the necessary variables in ExperimentalData
exampleData._setData()

# %%
## initialize the Monitor class and set values
monitor = Monitor()
monitor.figureUpdateFrequency = 5
monitor.objectPlot = "complex"  # complex abs angle
monitor.verboseLevel = "low"  # high: plot two figures, low: plot only one figure
monitor.objectZoom = 1.5  # control object plot FoV
monitor.probeZoom = 0.5  # control probe plot FoV

# %%
## initialize the Params class and set values
params = Params()
# main parameters
params.positionOrder = "random"  # 'sequential' or 'random'
params.propagator = (
    "Fresnel"  # Fraunhofer Fresnel ASP scaledASP polychromeASP scaledPolychromeASP
)
params.intensityConstraint = "standard"  # standard fluctuation exponential poission
# how do we want to reconstruct (all Switches are set to False by default)
params.gpuSwitch = False
params.probePowerCorrectionSwitch = True
params.modulusEnforcedProbeSwitch = False
params.comStabilizationSwitch = True
params.orthogonalizationSwitch = False
params.orthogonalizationFrequency = 10
params.fftshiftSwitch = False

# %%
## initialize the Reconstruction class and set values
reconstruction = Reconstruction(exampleData, params)
reconstruction.npsm = 1  # Number of probe modes to reconstruct
reconstruction.nosm = 1  # Number of object modes to reconstruct
reconstruction.nlambda = 1  # len(exampleData.spectralDensity) # Number of wavelength
reconstruction.nslice = 1  # Number of object slice

reconstruction.initialProbe = "circ"
reconstruction.initialObject = "ones"

# initialize probe and object
reconstruction.initializeObjectProbe()
# optional: customize initial probe quadratic phase
reconstruction.probe = reconstruction.probe * np.exp(
    1.0j
    * 2
    * np.pi
    / reconstruction.wavelength
    * (reconstruction.Xp**2 + reconstruction.Yp**2)
    / (2 * 6e-3)
)

# %%
# choose the reconstruction engine and set values
engine_mPIE = Engines.mPIE(reconstruction, exampleData, params, monitor)
engine_mPIE.numIterations = 50
engine_mPIE.betaProbe = 0.25
engine_mPIE.betaObject = 0.25
# start reconstruction
engine_mPIE.reconstruct()

plt.close("all")
# Out:
# mPIE:  92%|█████████▏| 46/50 [00:25<00:03,  1.21it/s]
# ptychogram:   0%|          | 0/100 [00:00<?, ?it/s]
# ptychogram:  25%|██▌       | 25/100 [00:00<00:00, 249.06it/s]
# ptychogram:  50%|█████     | 50/100 [00:00<00:00, 229.11it/s]
# ptychogram:  74%|███████▍  | 74/100 [00:00<00:00, 204.96it/s]
# ptychogram:  95%|█████████▌| 95/100 [00:00<00:00, 202.23it/s]
# mPIE:  94%|█████████▍| 47/50 [00:26<00:02,  1.37it/s]
# ptychogram:   0%|          | 0/100 [00:00<?, ?it/s]
# ptychogram:  23%|██▎       | 23/100 [00:00<00:00, 229.23it/s]
# ptychogram:  46%|████▌     | 46/100 [00:00<00:00, 227.31it/s]
# ptychogram:  69%|██████▉   | 69/100 [00:00<00:00, 201.23it/s]
# ptychogram:  90%|█████████ | 90/100 [00:00<00:00, 201.49it/s]
# mPIE:  96%|█████████▌| 48/50 [00:26<00:01,  1.50it/s]
# ptychogram:   0%|          | 0/100 [00:00<?, ?it/s]
# ptychogram:  21%|██        | 21/100 [00:00<00:00, 205.89it/s]
# ptychogram:  42%|████▏     | 42/100 [00:00<00:00, 198.52it/s]
# ptychogram:  62%|██████▏   | 62/100 [00:00<00:00, 196.36it/s]
# ptychogram:  83%|████████▎ | 83/100 [00:00<00:00, 201.38it/s]
# mPIE:  98%|█████████▊| 49/50 [00:27<00:00,  1.63it/s]
# ptychogram:   0%|          | 0/100 [00:00<?, ?it/s]
# ptychogram:  35%|███▌      | 35/100 [00:00<00:00, 339.60it/s]
# ptychogram:  69%|██████▉   | 69/100 [00:00<00:00, 325.69it/s]
# mPIE: 100%|██████████| 50/50 [00:27<00:00,  1.80it/s]

# %%
# reconstruction.saveResults("result.hdf5")
